# %% [markdown]
# # Project : Home_LLC : Fectors that Influence US home prices nationally

# %% [markdown]
# # 1. Data Collection:

# %% [markdown]
# ## * FEATURES (Influence Fectors) : Owners_Equity_Real Estate, Households, Interest_rates, Avg_Mortgage_Rate, GDP_Capita, Gov_Policies_Subsidies_Housing, Unemployment_Rate, Construction_Material_PPI

# %% [markdown]
# ## *TARGET : US_HPI

# %% [raw]
# References for DATASETS:
#
# 1.	Unemployment : https://fred.stlouisfed.org/series/UNRATE
# 2.	Interest rates : https://fred.stlouisfed.org/series/FEDFUNDS
# 3.	Government policies/ subsidies : https://fred.stlouisfed.org/series/L312051A027NBEA
# 4.	Mortgage values : https://fred.stlouisfed.org/series/MORTGAGE30US
# 5.	GDP : https://fred.stlouisfed.org/series/A939RX0Q048SBEA, https://www.worldometers.info/gdp/us-gdp/
# 6.	Supply and Demand : 1. Total households : https://fred.stlouisfed.org/series/TTLHH
#                         2. Households; Owners' Equity in Real Estate : https://fred.stlouisfed.org/series/OEHRENWBSHNO
# 7.	Construction Material Prices   : https://fred.stlouisfed.org/series/WPUSI012011

# %% [markdown]
# # 2. Data Preparation:

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Fector 1 : Fetch the Unemployment_Rate dataset 

df1_Unemp = pd.read_csv('Unemployment_Rate.csv')
df1_Unemp

# Changing Date column from object type to Date Type
df1_Unemp.DATE=pd.to_datetime(df1_Unemp['DATE'])

# Fetch the Year wise data from DATE column
df1_Unemp['Year'] = df1_Unemp['DATE'].dt.year
df1 = df1_Unemp.groupby('Year').mean().reset_index()
df1
# Out:
#     Year  Unemployment_Rate
# 0   2001           4.741667
# 1   2002           5.783333
# 2   2003           5.991667
# 3   2004           5.541667
# 4   2005           5.083333
# 5   2006           4.608333
# 6   2007           4.616667
# 7   2008           5.800000
# 8   2009           9.283333
# 9   2010           9.608333
# 10  2011           8.933333
# 11  2012           8.075000
# 12  2013           7.358333
# 13  2014           6.158333
# 14  2015           5.275000
# 15  2016           4.875000
# 16  2017           4.358333
# 17  2018           3.891667
# 18  2019           3.683333
# 19  2020           8.091667
# 20  2021           5.366667
# 21  2022           3.641667
# 22  2023           3.627273

# %%
# Fector 2 : Fetch the Construction_Material_PPI dataset 

df2_Constru_PPI = pd.read_csv('Construction_Material_PPI.csv')
df2_Constru_PPI

# Changing Date column from object type to Date Type
df2_Constru_PPI.DATE=pd.to_datetime(df2_Constru_PPI['DATE'])

# Fetch the Year wise data from DATE column
df2_Constru_PPI['Year'] = df2_Constru_PPI['DATE'].dt.year
df2 = df2_Constru_PPI.groupby('Year').mean().reset_index()
df2
# Out:
#     Year  Construction_Material_PPI
# 0   2001                 142.800000
# 1   2002                 144.008333
# 2   2003                 147.108333
# 3   2004                 161.475000
# 4   2005                 169.558333
# 5   2006                 180.241667
# 6   2007                 183.175000
# 7   2008                 196.441667
# 8   2009                 189.175000
# 9   2010                 194.500000
# 10  2011                 201.125000
# 11  2012                 205.825000
# 12  2013                 209.275000
# 13  2014                 214.450000
# 14  2015                 213.541667
# 15  2016                 213.891667
# 16  2017                 221.641667
# 17  2018                 235.750000
# 18  2019                 235.725000
# 19  2020                 239.183333
# 20  2021                 303.412750
# 21  2022                 341.533250
# 22  2023                 332.824400

# %%
# Fector 3 : Fetch the Gov_Policies_Subsidies_Housing dataset 

df3_Gov = pd.read_csv('Gov_Policies_Subsidies_Housing.csv')
df3_Gov

# Changing Date column from object type to Date Type
df3_Gov.DATE=pd.to_datetime(df3_Gov['DATE'])

# Fetch the Year wise data from DATE column
df3_Gov['Year'] = df3_Gov['DATE'].dt.year
df3 = df3_Gov.groupby('Year').mean().reset_index()
df3
# Out:
#     Year  Gov_Policies_Subsidies_Housing
# 0   2001                          20.573
# 1   2002                          24.183
# 2   2003                          25.930
# 3   2004                          27.201
# 4   2005                          27.651
# 5   2006                          28.604
# 6   2007                          29.512
# 7   2008                          29.876
# 8   2009                          32.883
# 9   2010                          32.669
# 10  2011                          34.230
# 11  2012                          33.283
# 12  2013                          33.213
# 13  2014                          33.806
# 14  2015                          34.859
# 15  2016                          37.550
# 16  2017                          35.771
# 17  2018                          38.859
# 18  2019                          40.185
# 19  2020                          44.147
# 20  2021                          45.299
# 21  2022                          48.021
# ...

# %%
# Fector 4 : Fetch the GDP dataset 

df4_GDP = pd.read_csv('GDP.csv')
df4_GDP

# Changing Date column from object type to Date Type
df4_GDP.DATE=pd.to_datetime(df4_GDP['DATE'])

# Fetch the Year wise data from DATE column
df4_GDP['Year'] = df4_GDP['DATE'].dt.year
df4 = df4_GDP.groupby('Year').mean().reset_index()
df4
# Out:
#     Year    GDP_Capita
# 0   2001  49893.250000
# 1   2002  50260.250000
# 2   2003  51189.000000
# 3   2004  52681.250000
# 4   2005  54014.250000
# 5   2006  54993.500000
# 6   2007  55560.000000
# 7   2008  55105.250000
# 8   2009  53212.500000
# 9   2010  54188.250000
# 10  2011  54603.000000
# 11  2012  55422.250000
# 12  2013  56171.750000
# 13  2014  57137.750000
# 14  2015  58363.250000
# 15  2016  58967.750000
# 16  2017  60000.750000
# 17  2018  61417.500000
# 18  2019  62605.500000
# 19  2020  60984.750000
# 20  2021  64412.500000
# 21  2022  65414.500000
# 22  2023  66500.666667

# %%
# Fector 5 : Fetch the Avg_Mortgage_Rate dataset 

df5_Avg_Mor = pd.read_csv('Avg_Mortgage_Rate.csv')
df5_Avg_Mor

# Changing Date column from object type to Date Type
df5_Avg_Mor.DATE=pd.to_datetime(df5_Avg_Mor['DATE'])

# Fetch the Year wise data from DATE column
df5_Avg_Mor['Year'] = df5_Avg_Mor['DATE'].dt.year
df5 = df5_Avg_Mor.groupby('Year').mean().reset_index()
df5
# Out:
#     Year  Avg_Mortgage_Rate
# 0   2001           6.965882
# 1   2002           6.537308
# 2   2003           5.826981
# 3   2004           5.839231
# 4   2005           5.866731
# 5   2006           6.413269
# 6   2007           6.337308
# 7   2008           6.027170
# 8   2009           5.036538
# 9   2010           4.689808
# 10  2011           4.447885
# 11  2012           3.657500
# 12  2013           3.975577
# 13  2014           4.168868
# 14  2015           3.850577
# 15  2016           3.654038
# 16  2017           3.989808
# 17  2018           4.544615
# 18  2019           3.935769
# 19  2020           3.111698
# 20  2021           2.957692
# 21  2022           5.344038
# 22  2023           6.810612

# %%
# Fector 6 : Fetch the Interest_Rates dataset 

df6_Int = pd.read_csv('Interest_Rates.csv')
df6_Int

# Changing Date column from object type to Date Type
df6_Int.DATE=pd.to_datetime(df6_Int['DATE'])

# Fetch the Year wise data from DATE column
df6_Int['Year'] = df6_Int['DATE'].dt.year
df6 = df6_Int.groupby('Year').mean().reset_index()
df6
# Out:
#     Year  Interest_rates
# 0   2001        3.887500
# 1   2002        1.666667
# 2   2003        1.127500
# 3   2004        1.349167
# 4   2005        3.213333
# 5   2006        4.964167
# 6   2007        5.019167
# 7   2008        1.927500
# 8   2009        0.160000
# 9   2010        0.175000
# 10  2011        0.101667
# 11  2012        0.140000
# 12  2013        0.107500
# 13  2014        0.089167
# 14  2015        0.132500
# 15  2016        0.395000
# 16  2017        1.001667
# 17  2018        1.831667
# 18  2019        2.158333
# 19  2020        0.375833
# 20  2021        0.080000
# 21  2022        1.683333
# 22  2023        4.996364

# %%
# Fector 7 : Fetch the Households dataset 

df7_Household = pd.read_csv('Households.csv')
df7_Household

# Changing Date column from object type to Date Type
df7_Household.DATE=pd.to_datetime(df7_Household['DATE'])

# Fetch the Year wise data from DATE column
df7_Household['Year'] = df7_Household['DATE'].dt.year
df7 = df7_Household.groupby('Year').mean().reset_index()
df7
# Out:
#     Year  Households
# 0   2001    108209.0
# 1   2002    109297.0
# 2   2003    111278.0
# 3   2004    112000.0
# 4   2005    113343.0
# 5   2006    114384.0
# 6   2007    116011.0
# 7   2008    116783.0
# 8   2009    117181.0
# 9   2010    117538.0
# 10  2011    119927.0
# 11  2012    121084.0
# 12  2013    122459.0
# 13  2014    123229.0
# 14  2015    124587.0
# 15  2016    125819.0
# 16  2017    126224.0
# 17  2018    127586.0
# 18  2019    128579.0
# 19  2020    128451.0
# 20  2021    129224.0
# 21  2022    131202.0
# 22  2023    131434.0

# %%
# Fector 8 : Fetch the Owners_Equity_Real Estate dataset 

df8_Owner_Equity_RE = pd.read_csv('Owners_Equity_Real Estate.csv')
df8_Owner_Equity_RE

# Changing Date column from object type to Date Type
df8_Owner_Equity_RE.DATE=pd.to_datetime(df8_Owner_Equity_RE['DATE'])

# Fetch the Year wise data from DATE column
df8_Owner_Equity_RE['Year'] = df8_Owner_Equity_RE['DATE'].dt.year
df8 = df8_Owner_Equity_RE.groupby('Year').mean().reset_index()
df8
# Out:
#     Year  Owners_Equity_Real Estate
# 0   2001                 9325.51600
# 1   2002                 9827.24350
# 2   2003                10537.55675
# 3   2004                11951.42600
# 4   2005                13696.23100
# 5   2006                14189.22900
# 6   2007                13203.93350
# 7   2008                11071.03675
# 8   2009                 9328.04425
# 9   2010                 8937.55950
# 10  2011                 8456.47325
# 11  2012                 8612.70250
# 12  2013                10197.93850
# 13  2014                11772.16300
# 14  2015                13190.64550
# 15  2016                14644.30075
# 16  2017                16246.78225
# 17  2018                17819.45750
# 18  2019                19035.60725
# 19  2020                21027.70175
# 20  2021                25450.06525
# 21  2022                30966.49850
# 22  2023                31534.03200

# %%
# Label : Fetch the CSUSHPISA Estate dataset 

df9_US_HPI = pd.read_csv('CSUSHPISA.csv')
df9_US_HPI

# Changing Date column from object type to Date Type
df9_US_HPI.DATE=pd.to_datetime(df9_US_HPI['DATE'])

# Fetch the Year wise data from DATE column
df9_US_HPI['Year'] = df9_US_HPI['DATE'].dt.year
df9 = df9_US_HPI.groupby('Year').mean().reset_index()
df9
# Out:
#     Year   CSUSHPISA
# 0   2001  113.179917
# 1   2002  122.279250
# 2   2003  133.731333
# 3   2004  150.440250
# 4   2005  171.737000
# 5   2006  183.447500
# 6   2007  179.918917
# 7   2008  164.057417
# 8   2009  148.545083
# 9   2010  144.674500
# 10  2011  139.259500
# 11  2012  140.993833
# 12  2013  154.520750
# 13  2014  164.698167
# 14  2015  172.181750
# 15  2016  180.925500
# 16  2017  191.397667
# 17  2018  202.476417
# 18  2019  209.463333
# 19  2020  222.143417
# 20  2021  260.045667
# 21  2022  298.486750
# 22  2023  303.074778

# %%
#df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9], axis =1)

df =pd.merge(df9,pd.merge(df8,pd.merge(df7,pd.merge(df6,pd.merge(df5,pd.merge(df4,pd.merge(df3,pd.merge(df1,df2,on='Year'),on='Year'),on='Year'),on='Year'),on='Year'),on='Year'),on='Year'),on='Year')

from sklearn.utils import shuffle
df=shuffle(df)
df.reset_index(drop=True)
# Out:
#     Year   CSUSHPISA  Owners_Equity_Real Estate  Households  Interest_rates  \
# 0   2013  154.520750                10197.93850    122459.0        0.107500
# 1   2018  202.476417                17819.45750    127586.0        1.831667
# 2   2004  150.440250                11951.42600    112000.0        1.349167
# 3   2007  179.918917                13203.93350    116011.0        5.019167
# 4   2020  222.143417                21027.70175    128451.0        0.375833
# 5   2012  140.993833                 8612.70250    121084.0        0.140000
# 6   2011  139.259500                 8456.47325    119927.0        0.101667
# 7   2016  180.925500                14644.30075    125819.0        0.395000
# 8   2015  172.181750                13190.64550    124587.0        0.132500
# 9   2017  191.397667                16246.78225    126224.0        1.001667
# 10  2021  260.045667                25450.06525    129224.0        0.080000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 12 to 1
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            23 non-null     int64
#  1   CSUSHPISA                       23 non-null     float64
#  2   Owners_Equity_Real Estate       23 non-null     float64
#  3   Households                      23 non-null     float64
#  4   Interest_rates                  23 non-null     float64
#  5   Avg_Mortgage_Rate               23 non-null     float64
#  6   GDP_Capita                      23 non-null     float64
#  7   Gov_Policies_Subsidies_Housing  23 non-null     float64
#  8   Unemployment_Rate               23 non-null     float64
#  9   Construction_Material_PPI       23 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 2.0 KB

# %% [markdown]
# As per observation:
# 1. The dataset has 23 rows and 10 columns.
# 2. No null value in any column.
# 3. Date data in float and int.

# %% [markdown]
# # 3. EDA:

# %%
df.rename(columns = {"CSUSHPISA":"US_HPI"},inplace=True)

# %% [markdown]
# # correlation of one variable vs all other variables, or multicorelation

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True, annot_kws={'size':10}, linewidths=0.1,fmt="0.2f")
plt.show()

# %% [markdown]
# # Data Visualization

# %%
# Now checking the distribution plot

# %%
plt.figure (figsize=(20,15))
plotnumber = 1

for column in df.columns:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)          
    plotnumber+=1
                     
plt.show()

# %% [raw]
# As per Observation, the dataset is normaly distributed, so it looks good.

# %%
plt.figure (figsize=(20,15))
plotnumber = 1

for column in df.columns:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)          
    plotnumber+=1
                     
plt.show()

# %%
df.describe()
# Out:
#              Year      US_HPI  Owners_Equity_Real Estate     Households  \
# count    23.00000   23.000000                  23.000000      23.000000
# mean   2012.00000  180.507769               14827.049750  120688.217391
# std       6.78233   50.621835                6733.717886    7242.702559
# min    2001.00000  113.179917                8456.473250  108209.000000
# 25%    2006.50000  146.609792               10012.591000  115197.500000
# 50%    2012.00000  171.737000               13190.645500  121084.000000
# 75%    2017.50000  196.937042               17033.119875  126905.000000
# max    2023.00000  303.074778               31534.032000  131434.000000
#
#        Interest_rates  Avg_Mortgage_Rate    GDP_Capita  \
# count       23.000000          23.000000     23.000000
# mean         1.590567           4.956039  57091.278986
# std          1.704417           1.238315   4745.878613
# min          0.080000           2.957692  49893.250000
# ...

# %% [raw]
# all values of dataset are true, so if any outlier than will handle it

# %%
x=df.drop(columns='US_HPI')
y=df.US_HPI

# %% [markdown]
# # Now Check correlation of the columns with the target column

# %%
#let's see relationship between features and label

plt.figure (figsize=(20,15),facecolor='y')
plotnumber = 1

for column in x:
    if plotnumber<=8:
        ax=plt.subplot(3,3,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('US_HPI',fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
df.corr()['US_HPI'].sort_values()
# Out:
# Unemployment_Rate                -0.493377
# Avg_Mortgage_Rate                -0.147022
# Interest_rates                    0.221289
# Households                        0.798648
# Year                              0.819599
# Gov_Policies_Subsidies_Housing    0.897462
# GDP_Capita                        0.931146
# Construction_Material_PPI         0.934796
# Owners_Equity_Real Estate         0.980731
# US_HPI                            1.000000
# Name: US_HPI, dtype: float64

# %%
plt.figure(figsize=(12,8))
df.corr()['US_HPI'].sort_values().plot(kind='bar')
plt.xlabel('Features')
plt.title('Correlation with target')
plt.show()

# %% [raw]
# As per observation, most of fectors have high coorelation with target variable, which are True for dataset.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='Unemployment_Rate',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# Unemployment_Rate changes year by year, it is high on 2009,2010 year, which may be not directly relate with target.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='Avg_Mortgage_Rate',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# Avg_Mortgage_Rate high in 2001 and 2023 year, which also not direclty relate with target, coz it's very year by year.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='Households',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# Households' value increases year by year, means demand goes high year by year.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='Gov_Policies_Subsidies_Housing',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# Government subsidies' value increases year by year, means demand goes high year by year, max high in 2023 year.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='GDP_Capita',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# GDP per Capita's value shows minor ups and downs year by year. But from last three years 2021,2022 and 2023 it continuously increase.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='Construction_Material_PPI',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
#  Construction Material cost increases year by year, means demand goes high year by year. it is max in 2022 year.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='Owners_Equity_Real Estate',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# Owners Equity in Real Estate shows big ups and downs year by year. But from 2011 year it continuously increase.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='US_HPI',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# US HPI also shows big ups and downs year by year. But from 2011 year it continuously increase.

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Year',y='Interest_rates',data=df,palette="Blues_d",ci=68)
plt.show()

# %% [raw]
# Interset_rates changes year by year, which shows it's not directly relate with target. It is high on 2006, 2007 and 2023 year.

# %%
x=df.drop(columns='US_HPI')
y=df.US_HPI

# %% [markdown]
# ## Data Scaling using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x_scaled
# Out:
#         Year  Owners_Equity_Real Estate  Households  Interest_rates  \
# 0   0.150756                  -0.702903    0.249987       -0.889687
# 1   0.904534                   0.454379    0.973781        0.144635
# 2  -1.206045                  -0.436646   -1.226543       -0.144815
# 3  -0.753778                  -0.246460   -0.660297        2.056807
# 4   1.206045                   0.941532    1.095896       -0.728715
# 5   0.000000                  -0.943611    0.055874       -0.870190
# 6  -0.150756                  -0.967334   -0.107463       -0.893186
# 7   0.603023                  -0.027749    0.724328       -0.717217
# 8   0.452267                  -0.248478    0.550403       -0.874690
# 9   0.753778                   0.215578    0.781504       -0.353279
# 10  1.356801                   1.613041    1.205023       -0.906184
# 11 -0.603023                  -0.570328   -0.551312        0.202125
# 12  1.507557                   2.450679    1.484263        0.055651
# ...

# %%
X=x_scaled
y=y

# %% [markdown]
# # 4. Regression Model Development

# %%
#import the necessary model algos.
#regression
from sklearn.linear_model import LinearRegression,Ridge,Lasso,RidgeCV,LassoCV, SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor,GradientBoostingRegressor,AdaBoostRegressor
from xgboost import XGBRegressor

#model selection
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.model_selection import KFold

#evaluation metrics
from sklearn.metrics import r2_score

# %%
LR = LinearRegression()
LSO= Lasso()
RIG= Ridge()
KNNR= KNeighborsRegressor()
RFR = RandomForestRegressor()
DTR = DecisionTreeRegressor()
SVr = SVR()
BAGR= BaggingRegressor()
GRAR= GradientBoostingRegressor()
ADAR= AdaBoostRegressor()
SGDR= SGDRegressor()
XGBR= XGBRegressor()

# %%
model=[LinearRegression(), Lasso(), Ridge(), KNeighborsRegressor(), RandomForestRegressor(), DecisionTreeRegressor(), SVR(), 
       BaggingRegressor(), GradientBoostingRegressor(), AdaBoostRegressor(), SGDRegressor(), XGBRegressor()]

models=['LR = LinearRegression()','LSO = Lasso()', 'RIG = Ridge()', 'KNNR = KNeighborsRegressor()',
        'RFR = RandomForestRegressor()', 'DTR = DecisionTreeRegressor()', 'SVr = SVR()', 'BAGR = BaggingRegressor()',
        'GRAR = GradientBoostingRegressor()', 'ADAR = AdaBoostRegressor()', 'SGDR= SGDRegressor()', 'XGBR= XGBRegressor()' ]

acc_result=[]
train_result=[]

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=51)

for i in range(len(model)):
    clf=model[i]
    clf.fit(x_train,y_train)
    
    x_pred=clf.predict(x_train)
    y_pred=clf.predict(x_test)
    
    train_result.append(round (r2_score(y_train,x_pred)*100,2))
    acc_result.append(round (r2_score(y_pred,y_test)*100,2))

Result_df=pd.DataFrame({'Model Name':models, 'Training Score:':train_result,'Accuracy Score (without tuning)':acc_result})
Result_df
# Out:
#                             Model Name  Training Score:  \
# 0              LR = LinearRegression()            99.54
# 1                        LSO = Lasso()            97.93
# 2                        RIG = Ridge()            98.15
# 3         KNNR = KNeighborsRegressor()            79.97
# 4        RFR = RandomForestRegressor()            95.57
# 5        DTR = DecisionTreeRegressor()           100.00
# 6                          SVr = SVR()             4.11
# 7            BAGR = BaggingRegressor()            98.47
# 8   GRAR = GradientBoostingRegressor()           100.00
# 9           ADAR = AdaBoostRegressor()            99.58
# 10                SGDR= SGDRegressor()            98.45
# 11                XGBR= XGBRegressor()           100.00
#
#     Accuracy Score (without tuning)
# 0                             99.31
# 1                             99.35
# 2                             97.97
# 3                             23.88
# 4                             83.41
# ...

# %% [markdown]
# ## 1.1 Linear Regression:

# %%
acc_train=[]
acc_test=[]

for i in range (0,10000):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=i)
    
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    
    x_lr_predict=lr.predict(x_train)
    y_lr_predict=lr.predict(x_test)
    
    acc_train.append(r2_score(y_train,x_lr_predict))
    acc_test.append(r2_score(y_test,y_lr_predict))
    

acc_train_index= acc_train.index(max(acc_train))    
print("Index of max vaule of train's accuracy_score at random_state:",acc_train_index)

acc_test_index= acc_test.index(max(acc_test))
print("Index of max vaule of test's accuracy_score at random_state:",acc_test_index)
# Out:
# Index of max vaule of train's accuracy_score at random_state: 3956
# Index of max vaule of test's accuracy_score at random_state: 6192

# %% [markdown]
# Always choose best training score from random_state, because
#
# 1. if training score >= testing score ==> chance of best fit or undetfit
# 2. if training score << testing score ==> overfit
# 3. if training score >> testing score ==> undetfit

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=3956)
    
lr.fit(x_train,y_train)
x_lr_predict=lr.predict(x_train)
y_lr_predict=lr.predict(x_test)
    
print ("The training accurancy @ 3956 state is:",r2_score(y_train,x_lr_predict))
print ("The testing accurancy @ 3956 state is:",r2_score(y_test,y_lr_predict))
# Out:
# The training accurancy @ 3956 state is: 0.9992881402470932
# The testing accurancy @ 3956 state is: 0.858653058450669

# %%
#Cross-Validation of the Model

kford_val=KFold(n_splits=10,shuffle=False)

Train_accuracy=r2_score(y_train,x_lr_predict)
Test_accuracy =r2_score(y_test,y_lr_predict)

from sklearn.model_selection import cross_val_score

for i in range (2,10):
    cv_score = cross_val_score(lr,X,y,cv=kford_val)
    cv_mean = cv_score.mean()
    print("At Cross fold", i, "the cv score is", cv_mean, "\n  accuracy score for training is", Train_accuracy,
          "\n& accuracy for testing is", Test_accuracy)
    print("\n")
# Out:
# At Cross fold 2 the cv score is 0.8299468677676277
#   accuracy score for training is 0.9992881402470932
# & accuracy for testing is 0.858653058450669
#
#
# At Cross fold 3 the cv score is 0.8299468677676277
#   accuracy score for training is 0.9992881402470932
# & accuracy for testing is 0.858653058450669
#
#
# At Cross fold 4 the cv score is 0.8299468677676277
#   accuracy score for training is 0.9992881402470932
# & accuracy for testing is 0.858653058450669
#
#
# At Cross fold 5 the cv score is 0.8299468677676277
#   accuracy score for training is 0.9992881402470932
# & accuracy for testing is 0.858653058450669
#
#
# At Cross fold 6 the cv score is 0.8299468677676277
#   accuracy score for training is 0.9992881402470932
# & accuracy for testing is 0.858653058450669
#
#
# At Cross fold 7 the cv score is 0.8299468677676277
#   accuracy score for training is 0.9992881402470932
# & accuracy for testing is 0.858653058450669
#
#
# At Cross fold 8 the cv score is 0.8299468677676277
# ...

# %% [markdown]
# ## 1.2 Lasso Regression:

# %%
lasscv = LassoCV (alphas=None, max_iter= 100)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=100)

# %%
# best alpha parameter
alpha = lasscv.alpha_
las = Lasso(alpha)
las.fit(x_train,y_train)
las.score(x_train,y_train)
# Out:
# 0.9924476149769326

# %%
y_las_predict=las.predict(x_test)
r2_score(y_test,y_las_predict)
# Out:
# 0.8145881701680818

# %%
cv_score=cross_val_score(las,X,y,cv=kford_val)
cv_score.mean()
# Out:
# 0.5184130770253133

# %% [markdown]
# ## 1.3 Ridge Regression:

# %%
ridgecv = RidgeCV(alphas = np.arange(0.001,0.1,0.01))
ridgecv.fit(x_train,y_train)
alpha = ridgecv.alpha_

rig = Ridge (alpha)
rig.fit(x_train,y_train)
rig.score(x_train,y_train)
# Out:
# 0.9992755241321695

# %%
y_rig_predict=rig.predict(x_test)
r2_score(y_test,y_rig_predict)
# Out:
# 0.8530193941907742

# %%
cv_score=cross_val_score(rig,X,y,cv=kford_val)
cv_score.mean()
# Out:
# 0.8329717423904508

# %% [markdown]
# ## 1.4 KNeighbors Regressor:

# %%
knnr=KNeighborsRegressor(n_neighbors = 5)
knnr.fit(x_train,y_train)

y_knnr_predict=knnr.predict(x_test)
print('R2 Score:',r2_score(y_test,y_knnr_predict))

cv_score=cross_val_score(knnr,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: 0.3388370247836795
# Cross validation: 0.08815347336738785

# %% [markdown]
# ## 1.5 RandomForest Regression:

# %%
rfr=RandomForestRegressor(criterion='mse')

rfr.fit(x_train,y_train)

y_rfr_predict=rfr.predict(x_test)
print('R2 Score:',r2_score(y_test,y_rfr_predict))

cv_score=cross_val_score(rfr,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: 0.6718115902169219
# Cross validation: 0.7224359700703524

# %% [markdown]
# ## 1.6 Decision Tree Regression:

# %%
dtr=DecisionTreeRegressor(criterion='mse')

dtr.fit(x_train,y_train)

y_dtr_predict=dtr.predict(x_test)
print('R2 Score:',r2_score(y_test,y_dtr_predict))

cv_score=cross_val_score(dtr,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: 0.912469248598457
# Cross validation: 0.2564726660293305

# %% [markdown]
# ## 1.7 SVR:

# %%
svr=SVR(gamma='auto')

svr.fit(x_train,y_train)

y_svr_predict=svr.predict(x_test)
print('R2 Score:',r2_score(y_test,y_svr_predict))

cv_score=cross_val_score(svr,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: -0.23195588003192902
# Cross validation: -1.1357637272018466

# %% [markdown]
# ## 1.8 Bagging Regression:

# %%
bagr=BaggingRegressor(base_estimator=LinearRegression())

bagr.fit(x_train,y_train)

y_bagr_predict=bagr.predict(x_test)
print('R2 Score:',r2_score(y_test,y_bagr_predict))

cv_score=cross_val_score(bagr,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: 0.8865731735166376
# Cross validation: 0.7721601714127633

# %% [markdown]
# ## 1.9 Gradient Boosting Regression:

# %%
grar=GradientBoostingRegressor(criterion='friedman_mse', n_estimators=10, learning_rate=1)

grar.fit(x_train,y_train)

y_grar_predict=grar.predict(x_test)
print('R2 Score:',r2_score(y_test,y_grar_predict))

cv_score=cross_val_score(grar,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: -0.24062758108730198
# Cross validation: 0.2158909018433591

# %% [markdown]
# ## 1.10 AdaBoost Regression:

# %%
adar=AdaBoostRegressor(base_estimator=LinearRegression(),learning_rate=0.01)

adar.fit(x_train,y_train)

y_adar_predict=adar.predict(x_test)
print('R2 Score:',r2_score(y_test,y_adar_predict))

cv_score=cross_val_score(adar,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: 0.8592847913919688
# Cross validation: 0.8503613530175492

# %% [markdown]
# ## 1.11 SGDRegressor:

# %%
sgdr=SGDRegressor(alpha=0.1)

sgdr.fit(x_train,y_train)

y_sgdr_predict=sgdr.predict(x_test)
print('R2 Score:',r2_score(y_test,y_sgdr_predict))

cv_score=cross_val_score(sgdr,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: 0.8569688466340355
# Cross validation: 0.061619685746013585

# %% [markdown]
# ## 1.12 XGBRegressor:

# %%
xgbr=XGBRegressor(n_estimators = 10, learning_rate = 1)

xgbr.fit(x_train,y_train)

y_xgbr_predict=adar.predict(x_test)
print('R2 Score:',r2_score(y_test,y_xgbr_predict))

cv_score=cross_val_score(xgbr,X,y,cv=kford_val)
print ('Cross validation:',cv_score.mean())
# Out:
# R2 Score: 0.8592847913919688
# Cross validation: -0.6499484754618757

# %%
Acc_Score_tun =[round (r2_score(y_test,y_lr_predict)*100,2),
                round (r2_score(y_test,y_las_predict)*100,2),
                round (r2_score(y_test,y_rig_predict)*100,2),
                round (r2_score(y_test,y_knnr_predict)*100,2),
                round (r2_score(y_test,y_rfr_predict)*100,2),
                round (r2_score(y_test,y_dtr_predict)*100,2),
                round (r2_score(y_test,y_svr_predict)*100,2),
                round (r2_score(y_test,y_bagr_predict)*100,2),
                round (r2_score(y_test,y_grar_predict)*100,2),
                round (r2_score(y_test,y_adar_predict)*100,2),
                round (r2_score(y_test,y_sgdr_predict)*100,2),
                round (r2_score(y_test,y_xgbr_predict)*100,2)]

US_hpi = pd.DataFrame({'Regressor':['lr = LinearRegression()', 'las = Lasso()','rig = Ridge()',
                                'knn = KNeighborsRegressor()' ,'rf = RandomForestRegressor()', 'dt = DecisionTreeRegressor()',
                                 'svr = SVR()', 'bag = BaggingRegressor()', 'gra = GradientBoostingRegressor()',
                                 'adar = AdaBoostRegressor()','sgdr = SGDRegressor()', 'xgbr = XGBRegressor()'],
                                 
                                'Accuracy Score (with tuning)':Acc_Score_tun})
US_hpi
# Out:
#                             Regressor  Accuracy Score (with tuning)
# 0             lr = LinearRegression()                         85.87
# 1                       las = Lasso()                         81.46
# 2                       rig = Ridge()                         85.30
# 3         knn = KNeighborsRegressor()                         33.88
# 4        rf = RandomForestRegressor()                         67.18
# 5        dt = DecisionTreeRegressor()                         91.25
# 6                         svr = SVR()                        -23.20
# 7            bag = BaggingRegressor()                         88.66
# 8   gra = GradientBoostingRegressor()                        -24.06
# 9          adar = AdaBoostRegressor()                         85.93
# 10              sgdr = SGDRegressor()                         85.70
# 11              xgbr = XGBRegressor()                         85.93

# %%
US_HPI= pd.concat([Result_df,US_hpi],axis=1)
US_HPI
# Out:
#                             Model Name  Training Score:  \
# 0              LR = LinearRegression()            99.54
# 1                        LSO = Lasso()            97.93
# 2                        RIG = Ridge()            98.15
# 3         KNNR = KNeighborsRegressor()            79.97
# 4        RFR = RandomForestRegressor()            95.57
# 5        DTR = DecisionTreeRegressor()           100.00
# 6                          SVr = SVR()             4.11
# 7            BAGR = BaggingRegressor()            98.47
# 8   GRAR = GradientBoostingRegressor()           100.00
# 9           ADAR = AdaBoostRegressor()            99.58
# 10                SGDR= SGDRegressor()            98.45
# 11                XGBR= XGBRegressor()           100.00
#
#     Accuracy Score (without tuning)                          Regressor  \
# 0                             99.31            lr = LinearRegression()
# 1                             99.35                      las = Lasso()
# ...

# %% [markdown]
# # We are gettig high model accuracy: 99.31% in Linear Regression & 99.35% in Lasso model without tuning, means it shows models are performing exremely well, so we can save any model, but Linear Regression model has 82.9% cross validation score which is very good for model.
# # Save the model using pickle

# %%
import pickle
pickle.dump(LR,open('Zomato_Avg_Cost_of_Two-RegressionModel','wb'))
